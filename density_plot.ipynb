# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('merged.biallelicSNPs.table', sep='\t')

# %%
sns.kdeplot(data=data, x="AC").set(title='allele count (AC)')
# Out:
# [Text(0.5, 1.0, 'allele count (AC)')]

# %%
sns.kdeplot(data=data, x="AF").set(title='allele frequency (AF)')
# Out:
# [Text(0.5, 1.0, 'allele frequency (AF)')]

# %%
sns.kdeplot(data=data, x="BaseQRankSum").set(title='BaseQRankSum')
# Out:
# [Text(0.5, 1.0, 'BaseQRankSum')]

# %%
sns.kdeplot(data=data, x="DP").set(title='total depth (DP)')
# Out:
# [Text(0.5, 1.0, 'total depth (DP)')]

# %%
sns.kdeplot(data=data, x="ExcessHet").set(title='excess heterozygosity')
# Out:
# [Text(0.5, 1.0, 'excess heterozygosity')]

# %%
sns.kdeplot(data=data, x="FS").set(title='Strand bias (FS)')
# Out:
# [Text(0.5, 1.0, 'Strand bias (FS)')]

# %%
sns.kdeplot(data=data, x="InbreedingCoeff").set(title='Inbreeding coefficient')
# Out:
# [Text(0.5, 1.0, 'Inbreeding coefficient')]

# %%
sns.kdeplot(data=data, x="MQ").set(title='RMS Mapping Quality (MQ)')
# Out:
# [Text(0.5, 1.0, 'RMS Mapping Quality (MQ)')]

# %%
sns.kdeplot(data=data, x="MQRankSum").set(title='MQ Rank Sum')
# Out:
# [Text(0.5, 1.0, 'MQ Rank Sum')]

# %%
sns.kdeplot(data=data, x="QD").set(title='Variant Confidence (QD)')
# Out:
# [Text(0.5, 1.0, 'Variant Confidence (QD)')]

# %%
sns.kdeplot(data=data, x="ReadPosRankSum").set(title='ReadPosRankSum')
# Out:
# [Text(0.5, 1.0, 'ReadPosRankSum')]

# %%
sns.kdeplot(data=data, x="SOR").set(title='symmetric odds ratio')
# Out:
# [Text(0.5, 1.0, 'symmetric odds ratio')]
